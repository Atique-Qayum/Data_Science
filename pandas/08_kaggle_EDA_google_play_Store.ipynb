# %% [markdown]
# # Google Play Store EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# import ydata_profiling as yd

# %%
import pandas as pd
df = pd.read_csv('googleplaystore.csv')
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
# profile = yd.ProfileReport(df)
# profile.to_file(output_file='ydata_google_play_store.html')

# %%
# take samples from big dataset
df.sample(10)
# Out:
#                                                     App             Category  \
# 9570                         Spanish English Translator  BOOKS_AND_REFERENCE
# 5061                         AF Nutrition - Integratori   HEALTH_AND_FITNESS
# 4029                                  C BOOK-C PROGRAMS               FAMILY
# 2731   RetailMeNot - Coupons, Deals & Discount Shopping             SHOPPING
# 10814                              FR: My Secret Pets!                FAMILY
# 10640                       Florida HSMV Driver License               FAMILY
# 4712                                             WeChat        COMMUNICATION
# 1774                                     Bricks n Balls                 GAME
# 4289                      KDRAMA Amino for K-Drama Fans               SOCIAL
# 1154                               BBVA Compass Banking              FINANCE
#
#        Rating  Reviews                Size      Installs  Type Price  \
# 9570      4.2    87919  Varies with device   10,000,000+  Free     0
# 5061      NaN        6                 19M          100+  Free     0
# 4029      4.8      138                2.1M       10,000+  Free     0
# 2731      4.4   210208  Varies with device   10,000,000+  Free     0
# 10814     4.0      785                 31M       50,000+  Free     0
# 10640     3.9       14                 11M        1,000+  Free     0
# 4712      4.2  5387631  Varies with device  100,000,000+  Free     0
# 1774      4.4    30253  Varies with device    1,000,000+  Free     0
# 4289      4.6     4046                 63M      100,000+  Free     0
# 1154      4.3     5905                 50M      500,000+  Free     0
#
#       Content Rating             Genres        Last Updated  \
# 9570            Teen  Books & Reference        May 28, 2018
# 5061        Everyone   Health & Fitness      August 2, 2018
# 4029        Everyone          Education  September 22, 2017
# 2731        Everyone           Shopping      August 1, 2018
# 10814           Teen      Entertainment        June 3, 2015
# 10640       Everyone          Education    January 13, 2015
# 4712        Everyone      Communication       July 31, 2018
# 1774        Everyone             Casual      August 5, 2018
# 4289            Teen             Social       July 13, 2018
# 1154        Everyone            Finance       July 27, 2018
#
#               Current Ver         Android Ver
# 9570   Varies with device  Varies with device
# 5061                  1.3          4.1 and up
# 4029                  1.0          3.0 and up
# 2731   Varies with device  Varies with device
# 10814               1.3.1          3.0 and up
# 10640                 1.3          4.0 and up
# 4712   Varies with device  Varies with device
# 1774            1.0.1.049          4.1 and up
# 4289            1.8.19106        4.0.3 and up
# 1154                6.0.2          4.4 and up

# %%
# to do that let's have a look on unique values
df['Size'].value_counts()
# Out:
# Size
# Varies with device    1695
# 11M                    198
# 12M                    196
# 14M                    194
# 13M                    191
#                       ...
# 429k                     1
# 200k                     1
# 460k                     1
# 728k                     1
# 619k                     1
# Name: count, Length: 462, dtype: int64

# %%
df['Installs'].value_counts()
# Out:
# Installs
# 1,000,000+        1579
# 10,000,000+       1252
# 100,000+          1169
# 10,000+           1054
# 1,000+             907
# 5,000,000+         752
# 100+               719
# 500,000+           539
# 50,000+            479
# 5,000+             477
# 100,000,000+       409
# 10+                386
# 500+               330
# 50,000,000+        289
# 50+                205
# 5+                  82
# 500,000,000+        72
# 1+                  67
# 1,000,000,000+      58
# 0+                  14
# 0                    1
# Free                 1
# Name: count, dtype: int64

# %%
df['Price'].value_counts()
# Out:
# Price
# 0         10040
# $0.99       148
# $2.99       129
# $1.99        73
# $4.99        72
#           ...
# $1.75         1
# $14.00        1
# $4.85         1
# $46.99        1
# $1.04         1
# Name: count, Length: 93, dtype: int64

# %%
df['Price'].isnull().sum()
# Out:
# 0

# %%
# remove $ sign from all columns usning pandas
df['Price'] = df['Price'].str.replace('$', '')

print(df)
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10841 rows x 13 columns]

# %%
df['Price'].value_counts()
# Out:
# Price
# 0        10040
# 0.99       148
# 2.99       129
# 1.99        73
# 4.99        72
#          ...
# 1.75         1
# 14.00        1
# 4.85         1
# 46.99        1
# 1.04         1
# Name: count, Length: 93, dtype: int64
